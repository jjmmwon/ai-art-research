# %%
from crawler import Crawler

crawler = Crawler()

# 필터링 하고자 하는 키워드나 판매자를 설정할 수 있습니다.
# negative_keywords = ["prompt", "product", "template", "commission", "00", ...]
# negative_sellers = ["AIArtCenter", "OnlyNSFWHub", ...]
# crawler.set_negatives(
#     negative_keywords=negative_keywords,
#     negative_sellers=negative_sellers
# )

data = crawler.crawl(num_items=5)
data
# 예상치 못하게 프로그램이 종료되었을 경우 다시 실행하면 저장된 지점부터 다시 크롤링을 시작합니다.
# data = crawler.crawl(num_items=3000)
# Out:
#                                                title  price           seller  \
# 1  Custom Watercolor Portraits Using Pet Photo Pe...  16.08        ModPawsUS
# 2  Custom Pet Portrait Painting Canvas, Renaissan...  26.24  PrimeDesignArts
# 3  Misty Meow | Animal | Cat | Digital Art Print ...   1.01       CosmicMeta
# 4  Spanish Meowsterpiece | Pop Art | Digital Art ...   1.01       CosmicMeta
# 5  AI Generated Wall Art, , Printable Artwork, Be...   0.61     Cloud4dreams
# 0  Custom Royal Portrait from Photo, Renaissance ...  27.11   PethelangeloCo
#
#    num_seller_img  num_review_img  rating num_reviews reviews  \
# 1              10              20  4.8548       (40k)     NaN
# 2              11              20  4.9485      (3.5k)     NaN
# 3              11              20  4.9405      (2.4k)     NaN
# 4              11              20  4.9405      (2.4k)     NaN
# 5               6               1  4.5455        (13)     NaN
# ...
